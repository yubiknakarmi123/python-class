# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\python-class\week_5\nepal_bank_transactions.csv')

# %%
print(df.columns)
print("-"*80)
print(df.head())
print("-"*80)
print(df.tail())
# Out:
# Index(['transaction_id', 'date', 'time', 'branch_name', 'district', 'channel',
#        'transaction_type', 'card_type', 'account_type', 'amount_npr',
#        'response_code', 'response_message', 'transaction_status',
#        'customer_age', 'customer_gender', 'processing_time_ms'],
#       dtype='str')
# --------------------------------------------------------------------------------
#   transaction_id        date      time       branch_name   district  \
# 0     TXN0000001  2024-01-01  00:43:34     New Baneshwor  Kathmandu
# 1     TXN0000002  2024-01-01  01:04:46  Dhangadhi Branch    Kailali
# 2     TXN0000003  2024-01-01  06:41:33    Hetauda Branch  Makwanpur
# 3     TXN0000004  2024-01-01  07:46:42     Butwal Branch  Rupandehi
# 4     TXN0000005  2024-01-01  08:44:14   Janakpur Branch   Dhanusha
#
#             channel    transaction_type    card_type account_type  amount_npr  \
# 0               ATM      Mini Statement  Credit Card      Current        0.00
# 1  Internet Banking  Statement Download          NaN      Savings        0.00
# 2               ATM          PIN Change   Debit Card      Savings        0.00
# 3    Mobile Banking       Fund Transfer          NaN      Savings    97651.24
# 4               ATM      Mini Statement   Debit Card      Savings        0.00
#
#    response_code response_message transaction_status  customer_age  \
# 0              0         Approved            Success          26.0
# 1              0         Approved            Success          30.0
# 2              0         Approved            Success          58.0
# 3              0         Approved            Success          56.0
# 4              0         Approved            Success          37.0
#
#   customer_gender  processing_time_ms
# 0          Female                1322
# 1             NaN                 711
# 2          Female                1633
# 3          Female                 816
# 4            Male                1168
# --------------------------------------------------------------------------------
#      transaction_id        date      time       branch_name   district  \
# 6055     TXN0005996  2024-12-31  17:47:21    Kathmandu Main  Kathmandu
# 6056     TXN0005997  2024-12-31  18:22:58  Dhangadhi Branch    Kailali
# 6057     TXN0005998  2024-12-31  19:45:09    Birgunj Branch      Parsa
# 6058     TXN0005999  2024-12-31  21:00:21     New Baneshwor  Kathmandu
# 6059     TXN0006000  2024-12-31  22:32:17     Butwal Branch  Rupandehi
#
#              channel transaction_type   card_type account_type  amount_npr  \
# 6055  Mobile Banking  Balance Inquiry         NaN      Savings        0.00
# 6056             ATM  Cash Withdrawal  Debit Card      Savings     3000.00
# 6057  Mobile Banking    Fund Transfer         NaN      Savings    86174.23
# 6058             ATM  Cash Withdrawal  Debit Card      Savings     1000.00
# 6059  Mobile Banking       QR Payment         NaN      Savings     4014.87
#
#       response_code response_message transaction_status  customer_age  \
# 6055              0         Approved            Success          38.0
# 6056              0         Approved            Success          18.0
# 6057              0         Approved            Success          33.0
# 6058              0         Approved            Success          41.0
# 6059             55    Incorrect PIN           Reversed          18.0
#
#      customer_gender  processing_time_ms
# 6055          Female                 401
# 6056          Female                 970
# 6057            Male                 435
# 6058            Male                 901
# 6059          Female                 651

# %%
print(df.columns)
print("-"*80)
# Out:
# Index(['transaction_id', 'date', 'time', 'branch_name', 'district', 'channel',
#        'transaction_type', 'card_type', 'account_type', 'amount_npr',
#        'response_code', 'response_message', 'transaction_status',
#        'customer_age', 'customer_gender', 'processing_time_ms'],
#       dtype='str')
# --------------------------------------------------------------------------------

# %%
df.head()
# Out:
#   transaction_id        date      time       branch_name   district  \
# 0     TXN0000001  2024-01-01  00:43:34     New Baneshwor  Kathmandu
# 1     TXN0000002  2024-01-01  01:04:46  Dhangadhi Branch    Kailali
# 2     TXN0000003  2024-01-01  06:41:33    Hetauda Branch  Makwanpur
# 3     TXN0000004  2024-01-01  07:46:42     Butwal Branch  Rupandehi
# 4     TXN0000005  2024-01-01  08:44:14   Janakpur Branch   Dhanusha
#
#             channel    transaction_type    card_type account_type  amount_npr  \
# 0               ATM      Mini Statement  Credit Card      Current        0.00
# 1  Internet Banking  Statement Download          NaN      Savings        0.00
# 2               ATM          PIN Change   Debit Card      Savings        0.00
# 3    Mobile Banking       Fund Transfer          NaN      Savings    97651.24
# 4               ATM      Mini Statement   Debit Card      Savings        0.00
#
#    response_code response_message transaction_status  customer_age  \
# 0              0         Approved            Success          26.0
# 1              0         Approved            Success          30.0
# 2              0         Approved            Success          58.0
# 3              0         Approved            Success          56.0
# 4              0         Approved            Success          37.0
#
#   customer_gender  processing_time_ms
# 0          Female                1322
# 1             NaN                 711
# 2          Female                1633
# 3          Female                 816
# 4            Male                1168

# %%
df.tail()
# Out:
#      transaction_id        date      time       branch_name   district  \
# 6055     TXN0005996  2024-12-31  17:47:21    Kathmandu Main  Kathmandu
# 6056     TXN0005997  2024-12-31  18:22:58  Dhangadhi Branch    Kailali
# 6057     TXN0005998  2024-12-31  19:45:09    Birgunj Branch      Parsa
# 6058     TXN0005999  2024-12-31  21:00:21     New Baneshwor  Kathmandu
# 6059     TXN0006000  2024-12-31  22:32:17     Butwal Branch  Rupandehi
#
#              channel transaction_type   card_type account_type  amount_npr  \
# 6055  Mobile Banking  Balance Inquiry         NaN      Savings        0.00
# 6056             ATM  Cash Withdrawal  Debit Card      Savings     3000.00
# 6057  Mobile Banking    Fund Transfer         NaN      Savings    86174.23
# 6058             ATM  Cash Withdrawal  Debit Card      Savings     1000.00
# 6059  Mobile Banking       QR Payment         NaN      Savings     4014.87
#
#       response_code response_message transaction_status  customer_age  \
# 6055              0         Approved            Success          38.0
# 6056              0         Approved            Success          18.0
# 6057              0         Approved            Success          33.0
# 6058              0         Approved            Success          41.0
# 6059             55    Incorrect PIN           Reversed          18.0
#
#      customer_gender  processing_time_ms
# 6055          Female                 401
# 6056          Female                 970
# 6057            Male                 435
# 6058            Male                 901
# 6059          Female                 651

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6060 entries, 0 to 6059
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   transaction_id      6060 non-null   str
#  1   date                6060 non-null   str
#  2   time                6060 non-null   str
#  3   branch_name         6060 non-null   str
#  4   district            6060 non-null   str
#  5   channel             6060 non-null   str
#  6   transaction_type    6060 non-null   str
#  7   card_type           3461 non-null   str
#  8   account_type        6060 non-null   str
#  9   amount_npr          6060 non-null   float64
#  10  response_code       6060 non-null   int64
#  11  response_message    6060 non-null   str
#  12  transaction_status  6060 non-null   str
#  13  customer_age        5941 non-null   float64
#  14  customer_gender     5968 non-null   str
#  15  processing_time_ms  6060 non-null   int64
# dtypes: float64(2), int64(2), str(12)
# memory usage: 757.6 KB

# %%
df.shape
# Out:
# (6060, 16)

# %%
df["date"] = pd.to_datetime(df["date"])
df.dtypes
# Out:
# transaction_id                   str
# date                  datetime64[us]
# time                             str
# branch_name                      str
# district                         str
# channel                          str
# transaction_type                 str
# card_type                        str
# account_type                     str
# amount_npr                   float64
# response_code                  int64
# response_message                 str
# transaction_status               str
# customer_age                 float64
# customer_gender                  str
# processing_time_ms             int64
# dtype: object

# %%
df[["branch_name", "channel", "amount_npr"]].head()
# Out:
#         branch_name           channel  amount_npr
# 0     New Baneshwor               ATM        0.00
# 1  Dhangadhi Branch  Internet Banking        0.00
# 2    Hetauda Branch               ATM        0.00
# 3     Butwal Branch    Mobile Banking    97651.24
# 4   Janakpur Branch               ATM        0.00

# %%
print(df.loc[0, "branch_name"])
# Out:
# New Baneshwor

# %%
print(df.iloc[0,3])
# Out:
# New Baneshwor

# %%
df.loc[0:2, ["branch_name", "channel", "transaction_status"]]
# Out:
#         branch_name           channel transaction_status
# 0     New Baneshwor               ATM            Success
# 1  Dhangadhi Branch  Internet Banking            Success
# 2    Hetauda Branch               ATM            Success

# %%
atm_withdrawls=df[(df["channel"]=="ATM")&(df["transaction_type"]=="cash Withdrawl")]
print(f"ATM cash Withdrawls:{len(atm_withdrawls)}")
atm_withdrawls.head()
# Out:
# ATM cash Withdrawls:0
# Empty DataFrame
# Columns: [transaction_id, date, time, branch_name, district, channel, transaction_type, card_type, account_type, amount_npr, response_code, response_message, transaction_status, customer_age, customer_gender, processing_time_ms]
# Index: []

# %%
not_successful=df[df["transaction_status"]!="Success"]
print(f"Not successful:{len(not_successful)}out of {len(df)}({len(not_successful)/len(df):.1%})")
not_successful["transaction_status"].value_counts()
# Out:
# Not successful:629out of 6060(10.4%)
# transaction_status
# Timeout     223
# Failed      209
# Reversed    197
# Name: count, dtype: int64

# %%
large_transfers=df[(df["transaction_type"]=="Fund Transfer")&(df["amount_npr"]>50000)]
print(f"large Fund transfers(>NPR 50000):{len(large_transfers)}")
# Out:
# large Fund transfers(>NPR 50000):287

# %%
df.sort_values("amount_npr",ascending=False).head(10)[
    ["transaction_id","branch_name","transaction_type","amount_npr","transaction_status"]
]
# Out:
#      transaction_id          branch_name transaction_type  amount_npr  \
# 5500     TXN0005445        Dharan Branch     Cash Deposit   198498.26
# 1621     TXN0001605        New Baneshwor     Cash Deposit   194948.77
# 252      TXN0000249     Pokhara Lakeside     Cash Deposit   193797.93
# 103      TXN0000101       Birgunj Branch     Cash Deposit   183308.51
# 5960     TXN0005901     Bharatpur Branch     Cash Deposit   177534.63
# 713      TXN0000704    Lalitpur Branch       Cash Deposit   176521.96
# 3175     TXN0003137      Biratnagar Main     Cash Deposit   173506.79
# 5638     TXN0005581     Dhangadhi Branch     Cash Deposit   170886.57
# 5593     TXN0005536        New Baneshwor     Cash Deposit   169814.80
# 3748     TXN0003707       Hetauda Branch     Cash Deposit   161213.69
#
#      transaction_status
# 5500            Success
# 1621            Success
# 252             Success
# 103             Success
# 5960            Success
# 713             Success
# 3175           Reversed
# 5638            Success
# 5593            Success
# 3748            Success

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"]=(9.5, 6)
df["year_month"]= df["date"] .dt.to_period("M").astype(str)
df.head(2)
# Out:
#   transaction_id       date      time       branch_name   district  \
# 0     TXN0000001 2024-01-01  00:43:34     New Baneshwor  Kathmandu
# 1     TXN0000002 2024-01-01  01:04:46  Dhangadhi Branch    Kailali
#
#             channel    transaction_type    card_type account_type  amount_npr  \
# 0               ATM      Mini Statement  Credit Card      Current         0.0
# 1  Internet Banking  Statement Download          NaN      Savings         0.0
#
#    response_code response_message transaction_status  customer_age  \
# 0              0         Approved            Success          26.0
# 1              0         Approved            Success          30.0
#
#   customer_gender  processing_time_ms year_month
# 0          Female                1322    2024-01
# 1             NaN                 711    2024-01
